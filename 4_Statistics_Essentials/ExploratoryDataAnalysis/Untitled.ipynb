# %%
import numpy as np
import pandas as pd
df = pd.read_csv('EDA_census.csv')
df.head()
# Out:
#   Table Name  State Code  Distt Code Area Name Total/Rural/Urban Age-group  \
# 0      C2308           0           0     INDIA             Total  All ages
# 1      C2308           0           0     INDIA             Total       0-6
# 2      C2308           0           0     INDIA             Total         7
# 3      C2308           0           0     INDIA             Total         8
# 4      C2308           0           0     INDIA             Total         9
#
#    Total Persons  Total Males  Total Females  Illiterate Persons  ...  \
# 0     1210854977    623270258      587584719           447216165  ...
# 1      164515253     85752254       78762999           164515253  ...
# 2       24826640     12903364       11923276             6748214  ...
# 3       26968373     14061937       12906436             4131414  ...
# 4       23424638     12214985       11209653             2491904  ...
#
#    Literate TDip Persons  Literate TDip Males  Literate TDip Females  \
# ...

# %%
df = df.columns.str.strip()

# %%
df1 = df[df['Age-group'] =="20-24"]
df1.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-27432ad4ec25> in <module>
# ----> 1 df1 = df[df['Age-group'] =="20-24"]
#       2 df1.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3956         if is_scalar(key):
#    3957             key = com.cast_scalar_indexer(key)
# -> 3958             return getitem(key)
#    3959
#    3960         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
